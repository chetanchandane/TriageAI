# %%
import os
from dotenv import load_dotenv
from google import genai

load_dotenv()
# Out:
# True

# %%
client = genai.Client(api_key=os.environ.get("LLM_GEMINI_API_KEY"))
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="Write a short poem about the sea."
)
print(response.text)
# Out:
# A vast, blue breath, a restless sigh,
# Beneath the wide and boundless sky.
# With rhythmic crash and whispered foam,
# The ocean calls the wanderer home.
